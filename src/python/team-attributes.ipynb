# %% [markdown]
# # LIMPANDO OS DADOS DA NOSSA BASE
#
#
# ### TEAM ATTRIBUTES

# %%
import pandas as pd

# %%
base = pd.read_csv('Team_Attributes.csv')

# %%
base
# Out:
#     Unnamed: 0          ID ABBREVIATION       NICKNAME  YEARFOUNDED  \
# 0            0  1610612737          ATL          Hawks         1949
# 1            1  1610612738          BOS        Celtics         1946
# 2            2  1610612739          CLE      Cavaliers         1970
# 3            3  1610612740          NOP       Pelicans         2002
# 4            4  1610612741          CHI          Bulls         1966
# 5            5  1610612742          DAL      Mavericks         1980
# 6            6  1610612743          DEN        Nuggets         1976
# 7            7  1610612744          GSW       Warriors         1946
# 8            8  1610612745          HOU        Rockets         1967
# 9            9  1610612746          LAC       Clippers         1970
# 10          10  1610612747          LAL         Lakers         1948
# 11          11  1610612748          MIA           Heat         1988
# 12          12  1610612749          MIL          Bucks         1968
# ...

# %%
base.head()
# Out:
#    Unnamed: 0          ID ABBREVIATION   NICKNAME  YEARFOUNDED         CITY  \
# 0           0  1610612737          ATL      Hawks         1949      Atlanta
# 1           1  1610612738          BOS    Celtics         1946       Boston
# 2           2  1610612739          CLE  Cavaliers         1970    Cleveland
# 3           3  1610612740          NOP   Pelicans         2002  New Orleans
# 4           4  1610612741          CHI      Bulls         1966      Chicago
#
#                         ARENA  ARENACAPACITY            OWNER  \
# 0            State Farm Arena        18729.0     Tony Ressler
# 1                   TD Garden        18624.0    Wyc Grousbeck
# 2  Rocket Mortgage FieldHouse        20562.0      Dan Gilbert
# 3        Smoothie King Center            NaN       Tom Benson
# 4               United Center        21711.0  Jerry Reinsdorf
#
#        GENERALMANAGER       HEADCOACH DLEAGUEAFFILIATION  \
# 0      Travis Schlenk   Nate McMillan      Erie Bayhawks
# ...

# %%
base.groupby(["ID", "NICKNAME"] ).count()
# Out:
#                           Unnamed: 0  ABBREVIATION  YEARFOUNDED  CITY  ARENA  \
# ID         NICKNAME
# 1610612737 Hawks                   1             1            1     1      1
# 1610612738 Celtics                 1             1            1     1      1
# 1610612739 Cavaliers               1             1            1     1      1
# 1610612740 Pelicans                1             1            1     1      1
# 1610612741 Bulls                   1             1            1     1      1
# 1610612742 Mavericks               1             1            1     1      1
# 1610612743 Nuggets                 1             1            1     1      1
# 1610612744 Warriors                1             1            1     1      1
# 1610612745 Rockets                 1             1            1     1      1
# 1610612746 Clippers                1             1            1     1      1
# 1610612747 Lakers                  1             1            1     1      1
# ...

# %%
base = base[["ID", "NICKNAME"]]

# %%
display(base)
# Out:
#             ID       NICKNAME
# 0   1610612737          Hawks
# 1   1610612738        Celtics
# 2   1610612739      Cavaliers
# 3   1610612740       Pelicans
# 4   1610612741          Bulls
# 5   1610612742      Mavericks
# 6   1610612743        Nuggets
# 7   1610612744       Warriors
# 8   1610612745        Rockets
# 9   1610612746       Clippers
# 10  1610612747         Lakers
# 11  1610612748           Heat
# 12  1610612749          Bucks
# 13  1610612750   Timberwolves
# 14  1610612751           Nets
# 15  1610612752         Knicks
# 16  1610612753          Magic
# 17  1610612754         Pacers
# 18  1610612755          76ers
# 19  1610612756           Suns
# 20  1610612757  Trail Blazers
# 21  1610612758          Kings
# 22  1610612759          Spurs
# 23  1610612760        Thunder
# 24  1610612761        Raptors
# 25  1610612762           Jazz
# 26  1610612763      Grizzlies
# 27  1610612764        Wizards
# 28  1610612765        Pistons
# 29  1610612766        Hornets

# %%
base.to_csv
# Out:
# <bound method NDFrame.to_csv of             ID       NICKNAME
# 0   1610612737          Hawks
# 1   1610612738        Celtics
# 2   1610612739      Cavaliers
# 3   1610612740       Pelicans
# 4   1610612741          Bulls
# 5   1610612742      Mavericks
# 6   1610612743        Nuggets
# 7   1610612744       Warriors
# 8   1610612745        Rockets
# 9   1610612746       Clippers
# 10  1610612747         Lakers
# 11  1610612748           Heat
# 12  1610612749          Bucks
# 13  1610612750   Timberwolves
# 14  1610612751           Nets
# 15  1610612752         Knicks
# 16  1610612753          Magic
# 17  1610612754         Pacers
# 18  1610612755          76ers
# 19  1610612756           Suns
# 20  1610612757  Trail Blazers
# 21  1610612758          Kings
# 22  1610612759          Spurs
# 23  1610612760        Thunder
# 24  1610612761        Raptors
# 25  1610612762           Jazz
# 26  1610612763      Grizzlies
# 27  1610612764        Wizards
# 28  1610612765        Pistons
# ...
